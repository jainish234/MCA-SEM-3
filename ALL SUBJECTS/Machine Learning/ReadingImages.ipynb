# %% [markdown]
# ##Reading Images

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('fruits.jpeg')
plt.imshow(img)

# %% [markdown]
# #Removing Axis

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('fruits.jpeg')
plt.imshow(img)
#plt.xticks([])
#plt.yticks([])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(247.5), np.float64(147.5), np.float64(-0.5))

# %% [markdown]
# ##Shap of the Images

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('fruits.jpeg')
plt.imshow(img)
r,c=img.shape[:2]
print(r)
print(c)
# Out:
# 148
# 248
